# %% [markdown]
# # 7-3. **Transformer**
# This code is from https://tutorials.pytorch.kr/beginner/transformer_tutorial.html, pytorch official document about seq2seq modeling using Transformer.

# %%
# !pip3 install -q torchtext==0.4.0
# !mkdir -p .data/wikitext-2/
# !wget -P .data/wikitext-2/ https://raw.githubusercontent.com/kimtwan/NLP_lecture/master/data/wikitext-2-v1.zip
# !unzip .data/wikitext-2/wikitext-2-v1.zip -d .data/wikitext-2/wikitext-2/
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.4 MB/s eta 0:00:00
# --2026-05-22 06:59:34--  https://raw.githubusercontent.com/kimtwan/NLP_lecture/master/data/wikitext-2-v1.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4479486 (4.3M) [application/zip]
# Saving to: ‘.data/wikitext-2/wikitext-2-v1.zip’
#
# wikitext-2-v1.zip   100%[===================>]   4.27M  --.-KB/s    in 0.01s
#
# 2026-05-22 06:59:36 (381 MB/s) - ‘.data/wikitext-2/wikitext-2-v1.zip’ saved [4479486/4479486]
#
# Archive:  .data/wikitext-2/wikitext-2-v1.zip
#   inflating: .data/wikitext-2/wikitext-2/wiki.test.tokens
#   inflating: .data/wikitext-2/wikitext-2/wiki.train.tokens
#   inflating: .data/wikitext-2/wikitext-2/wiki.valid.tokens

# %% [markdown]
# **Sequence-to-Sequence Modeling with nn.Transformer and TorchText**
#
# This is a tutorial on how to train a sequence-to-sequence model
# that uses the
# [nn.Transformer](https://pytorch.org/docs/master/nn.html?highlight=nn%20transformer#torch.nn.Transformer) module.
#
# PyTorch 1.2 release includes a standard transformer module based on the
# paper [Attention is All You
# Need](https://arxiv.org/pdf/1706.03762.pdf) . The transformer model
# has been proved to be superior in quality for many sequence-to-sequence
# problems while being more parallelizable. The ``nn.Transformer`` module
# relies entirely on an attention mechanism (another module recently
# implemented as [nn.MultiheadAttention](https://pytorch.org/docs/master/nn.html?highlight=multiheadattention#torch.nn.MultiheadAttention) to draw global dependencies
# between input and output. The ``nn.Transformer`` module is now highly
# modularized such that a single component (like `nn.TransformerEncoder`
# in this tutorial) can be easily adapted/composed.
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_static/img/transformer_architecture.jpg?raw=1)

# %% [markdown]
# Define the model
# ----------------

# %% [markdown]
# In this tutorial, we train ``nn.TransformerEncoder`` model on a
# language modeling task. The language modeling task is to assign a
# probability for the likelihood of a given word (or a sequence of words)
# to follow a sequence of words.
#
# A sequence of tokens are passed to the embedding
# layer first, followed by a positional encoding layer to account for the order
# of the word (see the next paragraph for more details). The
# ``nn.TransformerEncoder`` consists of multiple layers of
# [nn.TransformerEncoderLayer](https://pytorch.org/docs/master/nn.html?highlight=transformerencoderlayer#torch.nn.TransformerEncoderLayer) . Along with the input sequence, a square
# attention mask is required because the self-attention layers in
# ``nn.TransformerEncoder`` are only allowed to attend the earlier positions in
# the sequence. For the language modeling task, any tokens on the future
# positions should be masked. To have the actual words, the output
# of ``nn.TransformerEncoder`` model is sent to the final Linear
# layer, which is followed by a log-Softmax function.

# %% [markdown]
# ### Transformer Model

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import TransformerEncoder, TransformerEncoderLayer

class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers,
                                                    enable_nested_tensor=False)
        self.embedding = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        # triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.embedding(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return output

# %% [markdown]
# #### Masking
# By passing the mask into the transformer_encoder forward() function, the attention will only be calculated on the earlier positions in the sequence.

# %%
# triu returns the upper triangular part of a matrix (2-D tensor) or batch of matrices (see section below)
torch.triu(torch.ones(3, 3))
# Out:
# tensor([[1., 1., 1.],
#         [0., 1., 1.],
#         [0., 0., 1.]])

# %%
# Masking
def masking():
    sz = 4
    mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))

    return mask

masking()
# Out:
# tensor([[0., -inf, -inf, -inf],
#         [0., 0., -inf, -inf],
#         [0., 0., 0., -inf],
#         [0., 0., 0., 0.]])

# %% [markdown]
# ### Positional Encoding

# %% [markdown]
# Transformer architecture takes base architecture of Seq2Seq model (Encoder - Decoder). However, the transformer does not use recurrent model so this means we need a module that captures sequence information of the input/output.
#
# ``PositionalEncoding`` module injects some information about the
# relative or absolute position of the tokens in the sequence. The
# positional encodings have the same dimension as the embeddings so that
# the two can be summed. Here, we use ``sine`` and ``cosine`` functions of
# different frequencies.

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term) #0::2 means starting with index 0, step = 2
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %% [markdown]
# Load and batch data
# -------------------

# %% [markdown]
# The training process uses Wikitext-2 dataset from ``torchtext``. The
# vocab object is built based on the train dataset and is used to numericalize
# tokens into tensors. Starting from sequential data, the ``batchify()``
# function arranges the dataset into columns, trimming off any tokens remaining
# after the data has been divided into batches of size ``batch_size``.
# For instance, with the alphabet as the sequence (total length of 26)
# and a batch size of 4, we would divide the alphabet into 4 sequences of
# length 6:
#
# \begin{align}\begin{bmatrix}
#   \text{A} & \text{B} & \text{C} & \ldots & \text{X} & \text{Y} & \text{Z}
#   \end{bmatrix}
#   \Rightarrow
#   \begin{bmatrix}
#   \begin{bmatrix}\text{A} \\ \text{B} \\ \text{C} \\ \text{D} \\ \text{E} \\ \text{F}\end{bmatrix} &
#   \begin{bmatrix}\text{G} \\ \text{H} \\ \text{I} \\ \text{J} \\ \text{K} \\ \text{L}\end{bmatrix} &
#   \begin{bmatrix}\text{M} \\ \text{N} \\ \text{O} \\ \text{P} \\ \text{Q} \\ \text{R}\end{bmatrix} &
#   \begin{bmatrix}\text{S} \\ \text{T} \\ \text{U} \\ \text{V} \\ \text{W} \\ \text{X}\end{bmatrix}
#   \end{bmatrix}\end{align}
#
# These columns are treated as independent by the model, which means that
# the dependence of ``G`` and ``F`` can not be learned, but allows more
# efficient batch processing.

# %%
import torchtext
from torchtext.data.utils import get_tokenizer
TEXT = torchtext.data.Field(tokenize=get_tokenizer('basic_english'),
                            init_token='<sos>',
                            eos_token='<eos>',
                            lower=True)
train_txt, val_txt, test_txt = torchtext.datasets.WikiText2.splits(TEXT)
TEXT.build_vocab(train_txt)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def batchify(data, bsz):
    data = TEXT.numericalize([data.examples[0].text])
    # Divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

batch_size = 20
eval_batch_size = 10
train_data = batchify(train_txt, batch_size)
val_data = batchify(val_txt, eval_batch_size)
test_data = batchify(test_txt, eval_batch_size)

# %%
print(train_data.shape)
print(val_data.shape)
# Out:
# torch.Size([104335, 20])
# torch.Size([21817, 10])

# %% [markdown]
# Functions to generate input and target sequence

# %% [markdown]
# ``get_batch()`` function generates the input and target sequence for
# the transformer model. It subdivides the source data into chunks of
# length ``bptt``. For the language modeling task, the model needs the
# following words as ``Target``. For example, with a ``bptt`` value of 2,
# we’d get the following two Variables for ``i`` = 0:
#
# ![](https://github.com/pytorch/tutorials/blob/gh-pages/_static/img/transformer_input_target.png?raw=1)
#
#
# It should be noted that the chunks are along dimension 0, consistent
# with the ``S`` dimension in the Transformer model. The batch dimension
# ``N`` is along dimension 1.

# %%
bptt = 35
def get_batch(source, i):
    seq_len = min(bptt, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target

# %%
print(get_batch(train_data, 0)[0].shape)
# Out:
# torch.Size([35, 20])

# %% [markdown]
# Initiate an instance
# --------------------

# %% [markdown]
# The model is set up with the hyperparameter below. The vocab size is
# equal to the length of the vocab object.

# %%
ntokens = len(TEXT.vocab.stoi) # the size of vocabulary
emsize = 200 # embedding dimension
nhid = 200 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 2 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 2 # the number of heads in the multiheadattention models
dropout = 0.2 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)

# %%
len(TEXT.vocab.stoi)
# Out:
# 28785

# %% [markdown]
# Run the model
# -------------

# %% [markdown]
# `CrossEntropyLoss `
# is applied to track the loss and
# `SGD `
# implements stochastic gradient descent method as the optimizer. The initial
# learning rate is set to 5.0. `StepLR ` is
# applied to adjust the learn rate through epochs. During the
# training, we use
# `nn.utils.clip_grad_norm_ `
# function to scale all the gradient together to prevent exploding.

# %%
criterion = nn.CrossEntropyLoss()
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

import time
def train(model, epoch, log_interval = 200):
    model.train() # Turn on the train mode
    total_loss = 0.
    start_time = time.time()
    for batch, i in enumerate(range(0, train_data.size(0) - 1, bptt)):
        data, targets = get_batch(train_data, i)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.2f} | ms/batch {:5.2f} | '
                  'loss {:5.2f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // bptt, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()


def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, bptt):
            data, targets = get_batch(data_source, i)
            output = eval_model(data)
            output_flat = output.view(-1, ntokens)
            total_loss += len(data) * criterion(output_flat, targets).item()
    return total_loss / (len(data_source) - 1)

# %% [markdown]
# Loop over epochs. Save the model if the validation loss is the best
# we've seen so far. Adjust the learning rate after each epoch.

# %%
best_val_loss = float('inf')
epochs = 3 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train(model, epoch)
    val_loss = evaluate(model, val_data)
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
          'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = model

    scheduler.step()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:656: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 18.14 | loss  8.08 | ppl  3223.81
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 16.67 | loss  6.82 | ppl   919.19
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 14.34 | loss  6.39 | ppl   596.93
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 13.63 | loss  6.25 | ppl   517.20
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 13.74 | loss  6.13 | ppl   461.01
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 13.51 | loss  6.10 | ppl   445.88
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 13.50 | loss  6.05 | ppl   423.84
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 13.51 | loss  6.05 | ppl   426.00
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 14.01 | loss  5.97 | ppl   393.03
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 13.55 | loss  5.97 | ppl   390.72
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 13.60 | loss  5.85 | ppl   348.87
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 13.60 | loss  5.91 | ppl   368.13
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 13.94 | loss  5.90 | ppl   365.62
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 14.08 | loss  5.81 | ppl   333.59
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 44.32s | valid loss  5.71 | valid ppl   302.27
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 14.02 | loss  5.81 | ppl   333.97
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 14.18 | loss  5.79 | ppl   325.56
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 14.23 | loss  5.61 | ppl   272.67
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 14.04 | loss  5.65 | ppl   283.42
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 14.09 | loss  5.59 | ppl   268.85
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 14.25 | loss  5.63 | ppl   278.12
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 14.56 | loss  5.63 | ppl   279.74
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 16.21 | loss  5.67 | ppl   290.95
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 14.34 | loss  5.60 | ppl   270.37
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 14.40 | loss  5.63 | ppl   278.05
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 14.87 | loss  5.52 | ppl   249.59
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 14.51 | loss  5.58 | ppl   266.20
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 14.55 | loss  5.59 | ppl   267.05
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 14.62 | loss  5.52 | ppl   248.60
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 45.14s | valid loss  5.62 | valid ppl   275.53
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 14.78 | loss  5.56 | ppl   258.99
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 14.76 | loss  5.56 | ppl   260.47
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 14.91 | loss  5.37 | ppl   215.77
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 15.13 | loss  5.43 | ppl   227.94
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 14.95 | loss  5.38 | ppl   217.74
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 15.01 | loss  5.42 | ppl   226.30
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 15.11 | loss  5.45 | ppl   232.02
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 15.32 | loss  5.49 | ppl   241.67
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 15.06 | loss  5.41 | ppl   224.50
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 15.00 | loss  5.46 | ppl   234.22
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 14.92 | loss  5.33 | ppl   206.65
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 15.25 | loss  5.41 | ppl   223.12
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 14.81 | loss  5.42 | ppl   226.29
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 14.74 | loss  5.35 | ppl   210.48
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 46.55s | valid loss  5.53 | valid ppl   252.76
# -----------------------------------------------------------------------------------------

# %% [markdown]
# Evaluate the model with the test dataset
# -------------------------------------
#
# Apply the best model to check the result with the test dataset.

# %%
test_loss = evaluate(best_model, test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# =========================================================================================
# | End of training | test loss  5.44 | test ppl   229.55
# =========================================================================================

# %% [markdown]
# # Exercise
# Try different number of heads in Multi-head Attention, or different number of encoders, and record the test performance. Draw a graph to show the test performance (validation losses/ppls) vs number of heads, or the test performance (validation losses/ppls) vs number of encoders, (you can keep epochs = 3)

# %%
import matplotlib.pyplot as plt

# %%
test_losses = []
val_epoch_losses = []
nlayers_range = [i for i in range(1,9)]

for nlayers in nlayers_range:
    print('-' * 89)
    print('{} encoders'.format(nlayers))
    print('-' * 89)
    # define a model, an optimizer, a scheduler
    # Please complete this
    lr = 5.0
    epochs = 3 # The number of epochs
    model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout).to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

    # train the model
    val_losses = []
    best_val_loss = float('inf')

    best_model = None
    # Please complete this
    for epoch in range(1, epochs + 1):
        epoch_start_time = time.time()
        train(model, epoch)
        val_loss = evaluate(model, val_data)
        val_losses.append(val_loss)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
              'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                         val_loss, math.exp(val_loss)))
        print('-' * 89)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = model

        scheduler.step()

    val_epoch_losses.append(val_losses)
    test_loss = evaluate(best_model, test_data)
    test_losses.append(test_loss)
    print('-' * 89)
    print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
        test_loss, math.exp(test_loss)))
    print('-' * 89)
# Out:
# -----------------------------------------------------------------------------------------
# 1 encoders
# -----------------------------------------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:656: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 12.71 | loss  7.73 | ppl  2267.16
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 12.46 | loss  6.67 | ppl   784.50
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 12.46 | loss  6.30 | ppl   546.15
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 12.62 | loss  6.20 | ppl   493.68
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 12.72 | loss  6.11 | ppl   448.14
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 12.57 | loss  6.10 | ppl   445.72
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 12.63 | loss  6.06 | ppl   429.02
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 12.64 | loss  6.08 | ppl   437.39
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 12.89 | loss  5.98 | ppl   395.64
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 12.91 | loss  6.00 | ppl   402.16
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 12.83 | loss  5.90 | ppl   365.41
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 12.90 | loss  5.95 | ppl   384.27
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 12.92 | loss  5.96 | ppl   387.70
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 13.18 | loss  5.88 | ppl   357.90
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 39.59s | valid loss  5.83 | valid ppl   340.64
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 13.13 | loss  5.86 | ppl   349.41
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 13.11 | loss  5.83 | ppl   339.01
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 13.35 | loss  5.68 | ppl   292.15
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 13.34 | loss  5.73 | ppl   307.60
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 13.33 | loss  5.69 | ppl   296.39
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 13.36 | loss  5.72 | ppl   303.89
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 13.43 | loss  5.73 | ppl   309.05
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 13.62 | loss  5.77 | ppl   320.59
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 13.52 | loss  5.70 | ppl   298.10
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 13.52 | loss  5.73 | ppl   309.51
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 13.53 | loss  5.65 | ppl   283.80
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 13.65 | loss  5.70 | ppl   298.50
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 13.71 | loss  5.71 | ppl   302.85
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 13.62 | loss  5.66 | ppl   286.56
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 41.70s | valid loss  5.71 | valid ppl   302.82
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 13.94 | loss  5.67 | ppl   290.51
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 14.04 | loss  5.66 | ppl   288.45
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 13.99 | loss  5.50 | ppl   244.96
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 13.85 | loss  5.56 | ppl   259.97
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 13.79 | loss  5.52 | ppl   249.19
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 13.93 | loss  5.56 | ppl   258.70
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 13.53 | loss  5.58 | ppl   266.04
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 13.55 | loss  5.60 | ppl   270.55
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 13.51 | loss  5.55 | ppl   257.82
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 13.66 | loss  5.59 | ppl   266.78
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 13.66 | loss  5.50 | ppl   244.71
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 13.50 | loss  5.56 | ppl   259.35
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 13.50 | loss  5.57 | ppl   261.40
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 13.51 | loss  5.51 | ppl   247.94
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 42.45s | valid loss  5.69 | valid ppl   297.37
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  5.61 | test ppl   274.15
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# 2 encoders
# -----------------------------------------------------------------------------------------
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 14.70 | loss  8.20 | ppl  3640.41
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 14.63 | loss  6.83 | ppl   928.88
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 14.95 | loss  6.39 | ppl   595.89
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 14.65 | loss  6.25 | ppl   517.93
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 14.68 | loss  6.13 | ppl   459.57
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 14.67 | loss  6.10 | ppl   445.85
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 14.93 | loss  6.06 | ppl   427.24
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 14.83 | loss  6.06 | ppl   427.60
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 14.67 | loss  5.98 | ppl   393.50
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 14.70 | loss  5.96 | ppl   389.35
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 14.87 | loss  5.86 | ppl   350.53
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 14.90 | loss  5.90 | ppl   365.74
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 14.81 | loss  5.91 | ppl   367.70
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 14.73 | loss  5.81 | ppl   332.22
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 46.04s | valid loss  5.70 | valid ppl   297.80
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 14.81 | loss  5.81 | ppl   334.56
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 14.73 | loss  5.78 | ppl   324.85
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 14.74 | loss  5.61 | ppl   272.31
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 15.10 | loss  5.65 | ppl   285.23
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 14.73 | loss  5.60 | ppl   270.49
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 14.71 | loss  5.63 | ppl   279.36
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 14.68 | loss  5.64 | ppl   281.87
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 14.96 | loss  5.68 | ppl   291.99
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 14.77 | loss  5.60 | ppl   270.26
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 14.71 | loss  5.63 | ppl   279.09
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 14.69 | loss  5.52 | ppl   249.42
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 14.87 | loss  5.59 | ppl   266.97
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 14.87 | loss  5.60 | ppl   270.20
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 14.66 | loss  5.53 | ppl   251.11
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 45.87s | valid loss  5.62 | valid ppl   275.28
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 15.05 | loss  5.57 | ppl   262.91
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 14.70 | loss  5.57 | ppl   261.48
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 14.71 | loss  5.38 | ppl   216.15
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 14.64 | loss  5.43 | ppl   228.76
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 14.92 | loss  5.39 | ppl   219.77
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 14.77 | loss  5.42 | ppl   225.78
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 14.70 | loss  5.44 | ppl   230.93
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 14.68 | loss  5.48 | ppl   240.37
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 14.87 | loss  5.42 | ppl   225.55
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 14.78 | loss  5.45 | ppl   232.31
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 14.66 | loss  5.33 | ppl   206.94
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 14.68 | loss  5.41 | ppl   224.05
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 14.88 | loss  5.42 | ppl   225.13
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 14.93 | loss  5.35 | ppl   210.64
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 45.88s | valid loss  5.50 | valid ppl   243.52
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  5.40 | test ppl   221.71
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# 3 encoders
# -----------------------------------------------------------------------------------------
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 16.23 | loss  8.39 | ppl  4389.99
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 16.12 | loss  7.14 | ppl  1266.27
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 15.94 | loss  6.59 | ppl   725.58
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 15.92 | loss  6.36 | ppl   577.93
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 16.27 | loss  6.20 | ppl   493.79
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 15.96 | loss  6.15 | ppl   469.70
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 15.92 | loss  6.09 | ppl   440.09
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 15.90 | loss  6.08 | ppl   438.92
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 16.35 | loss  5.99 | ppl   398.27
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 15.92 | loss  5.98 | ppl   396.04
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 16.01 | loss  5.86 | ppl   352.32
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 16.04 | loss  5.91 | ppl   368.53
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 16.50 | loss  5.91 | ppl   369.42
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 15.96 | loss  5.81 | ppl   333.79
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 49.95s | valid loss  5.75 | valid ppl   314.23
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 16.44 | loss  5.83 | ppl   341.85
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 16.07 | loss  5.82 | ppl   335.60
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 15.96 | loss  5.65 | ppl   284.12
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 15.92 | loss  5.67 | ppl   289.02
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 16.37 | loss  5.61 | ppl   272.33
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 15.91 | loss  5.63 | ppl   279.00
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 15.93 | loss  5.63 | ppl   279.91
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 15.92 | loss  5.66 | ppl   287.78
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 16.38 | loss  5.59 | ppl   268.15
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 15.91 | loss  5.62 | ppl   275.43
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 15.92 | loss  5.51 | ppl   247.11
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 16.04 | loss  5.58 | ppl   264.07
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 16.37 | loss  5.58 | ppl   264.74
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 15.97 | loss  5.50 | ppl   245.75
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 50.00s | valid loss  5.61 | valid ppl   273.06
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 16.60 | loss  5.56 | ppl   258.95
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 15.94 | loss  5.57 | ppl   262.76
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 15.94 | loss  5.38 | ppl   217.45
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 16.03 | loss  5.43 | ppl   228.07
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 16.34 | loss  5.38 | ppl   216.54
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 15.94 | loss  5.42 | ppl   224.81
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 15.95 | loss  5.42 | ppl   226.99
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 16.11 | loss  5.47 | ppl   236.40
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 16.21 | loss  5.39 | ppl   219.54
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 15.94 | loss  5.43 | ppl   227.99
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 15.99 | loss  5.31 | ppl   201.87
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 16.19 | loss  5.38 | ppl   216.00
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 16.17 | loss  5.39 | ppl   220.05
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 15.92 | loss  5.32 | ppl   204.89
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 50.11s | valid loss  5.50 | valid ppl   245.90
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  5.42 | test ppl   225.47
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# 4 encoders
# -----------------------------------------------------------------------------------------
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 17.23 | loss  8.43 | ppl  4581.35
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 17.17 | loss  7.44 | ppl  1699.17
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 17.30 | loss  7.19 | ppl  1325.61
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 17.32 | loss  7.07 | ppl  1175.45
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 17.11 | loss  6.98 | ppl  1069.57
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 17.03 | loss  6.71 | ppl   824.24
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 17.60 | loss  6.45 | ppl   635.79
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 17.08 | loss  6.35 | ppl   574.04
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 17.11 | loss  6.21 | ppl   500.17
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 17.27 | loss  6.16 | ppl   475.76
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 17.39 | loss  6.03 | ppl   417.40
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 17.05 | loss  6.04 | ppl   420.39
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 17.06 | loss  6.03 | ppl   417.63
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 17.70 | loss  5.93 | ppl   376.19
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 53.73s | valid loss  5.89 | valid ppl   361.31
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 17.06 | loss  5.93 | ppl   377.71
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 17.59 | loss  5.92 | ppl   372.91
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 17.06 | loss  5.80 | ppl   329.95
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 17.02 | loss  5.84 | ppl   343.47
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 17.23 | loss  5.77 | ppl   321.44
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 17.46 | loss  5.78 | ppl   322.86
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 17.03 | loss  5.76 | ppl   316.95
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 17.10 | loss  5.76 | ppl   317.77
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 17.55 | loss  5.68 | ppl   294.21
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 17.15 | loss  5.70 | ppl   300.15
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 17.06 | loss  5.58 | ppl   265.85
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 16.99 | loss  5.65 | ppl   283.62
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 17.62 | loss  5.66 | ppl   285.82
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 17.02 | loss  5.57 | ppl   263.34
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 53.63s | valid loss  5.61 | valid ppl   273.31
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 17.69 | loss  5.62 | ppl   275.25
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 16.99 | loss  5.64 | ppl   280.85
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 17.09 | loss  5.48 | ppl   240.47
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 17.46 | loss  5.54 | ppl   255.57
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 17.37 | loss  5.50 | ppl   243.78
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 17.01 | loss  5.52 | ppl   250.37
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 17.05 | loss  5.52 | ppl   250.76
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 17.77 | loss  5.55 | ppl   256.52
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 17.02 | loss  5.47 | ppl   237.89
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 17.10 | loss  5.50 | ppl   243.63
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 17.36 | loss  5.38 | ppl   216.13
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 17.46 | loss  5.45 | ppl   232.31
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 17.03 | loss  5.46 | ppl   235.13
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 17.09 | loss  5.39 | ppl   218.89
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 53.92s | valid loss  5.52 | valid ppl   248.91
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  5.43 | test ppl   228.11
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# 5 encoders
# -----------------------------------------------------------------------------------------
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 18.39 | loss  8.43 | ppl  4580.89
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 19.26 | loss  7.50 | ppl  1800.17
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 18.37 | loss  7.18 | ppl  1310.49
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 18.37 | loss  7.09 | ppl  1202.00
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 18.88 | loss  7.03 | ppl  1132.21
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 18.80 | loss  7.00 | ppl  1100.03
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 18.26 | loss  6.96 | ppl  1057.04
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 18.48 | loss  6.97 | ppl  1066.30
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 19.07 | loss  6.95 | ppl  1044.14
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 18.27 | loss  6.96 | ppl  1052.54
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 18.30 | loss  6.93 | ppl  1020.81
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 19.28 | loss  6.93 | ppl  1022.39
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 18.26 | loss  6.92 | ppl  1016.63
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 18.20 | loss  6.90 | ppl   987.83
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 58.34s | valid loss  6.77 | valid ppl   868.75
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 18.28 | loss  6.93 | ppl  1022.16
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 18.14 | loss  6.91 | ppl  1003.39
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 19.37 | loss  6.88 | ppl   970.05
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 18.23 | loss  6.91 | ppl   997.55
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 18.16 | loss  6.89 | ppl   986.31
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 18.94 | loss  6.91 | ppl  1004.49
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 18.59 | loss  6.89 | ppl   985.12
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 18.27 | loss  6.91 | ppl  1005.23
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 18.39 | loss  6.88 | ppl   975.53
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 18.87 | loss  6.89 | ppl   984.96
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 18.21 | loss  6.77 | ppl   871.12
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 18.31 | loss  6.56 | ppl   707.22
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 19.22 | loss  6.44 | ppl   627.09
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 18.31 | loss  6.26 | ppl   523.19
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 57.99s | valid loss  6.15 | valid ppl   469.33
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 19.23 | loss  6.13 | ppl   461.38
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 18.41 | loss  6.08 | ppl   438.79
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 18.42 | loss  5.94 | ppl   379.19
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 19.34 | loss  5.96 | ppl   386.47
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 18.36 | loss  5.88 | ppl   358.54
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 18.36 | loss  5.90 | ppl   363.52
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 19.18 | loss  5.87 | ppl   354.17
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 18.44 | loss  5.89 | ppl   362.77
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 18.43 | loss  5.82 | ppl   336.55
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 18.61 | loss  5.84 | ppl   343.16
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 18.93 | loss  5.72 | ppl   303.86
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 18.34 | loss  5.74 | ppl   311.23
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 18.37 | loss  5.74 | ppl   309.73
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 19.20 | loss  5.63 | ppl   279.23
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 58.28s | valid loss  5.66 | valid ppl   286.23
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  5.57 | test ppl   262.66
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# 6 encoders
# -----------------------------------------------------------------------------------------
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 20.76 | loss  8.36 | ppl  4271.26
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 20.17 | loss  7.47 | ppl  1751.73
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 20.30 | loss  7.20 | ppl  1333.58
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 20.59 | loss  7.08 | ppl  1183.33
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 20.07 | loss  7.05 | ppl  1157.20
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 20.36 | loss  7.01 | ppl  1111.16
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 20.75 | loss  6.97 | ppl  1062.47
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 20.19 | loss  6.97 | ppl  1059.16
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 20.35 | loss  6.95 | ppl  1038.33
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 20.73 | loss  6.96 | ppl  1053.18
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 20.18 | loss  6.93 | ppl  1022.21
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 20.40 | loss  6.92 | ppl  1017.19
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 20.63 | loss  6.92 | ppl  1013.68
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 20.07 | loss  6.90 | ppl   988.95
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 64.19s | valid loss  6.78 | valid ppl   876.30
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 20.17 | loss  6.93 | ppl  1021.29
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 20.18 | loss  6.91 | ppl  1005.91
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 20.92 | loss  6.88 | ppl   972.81
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 20.18 | loss  6.90 | ppl   995.41
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 20.18 | loss  6.90 | ppl   990.18
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 20.82 | loss  6.91 | ppl  1005.16
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 20.17 | loss  6.89 | ppl   984.16
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 20.19 | loss  6.91 | ppl  1003.01
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 20.93 | loss  6.89 | ppl   982.22
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 20.15 | loss  6.91 | ppl  1000.69
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 20.20 | loss  6.88 | ppl   976.84
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 21.25 | loss  6.89 | ppl   981.78
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 20.20 | loss  6.88 | ppl   977.46
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 20.17 | loss  6.86 | ppl   956.87
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 63.85s | valid loss  6.77 | valid ppl   869.14
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 20.21 | loss  6.90 | ppl   991.09
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 20.49 | loss  6.89 | ppl   978.42
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 20.59 | loss  6.86 | ppl   949.59
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 20.17 | loss  6.88 | ppl   977.45
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 20.40 | loss  6.88 | ppl   968.04
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 20.60 | loss  6.89 | ppl   985.86
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 20.16 | loss  6.87 | ppl   967.31
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 20.34 | loss  6.89 | ppl   980.47
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 20.65 | loss  6.87 | ppl   964.07
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 20.20 | loss  6.89 | ppl   978.42
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 20.52 | loss  6.86 | ppl   950.84
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 20.70 | loss  6.86 | ppl   950.37
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 20.17 | loss  6.86 | ppl   953.00
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 20.33 | loss  6.84 | ppl   934.16
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 63.76s | valid loss  6.75 | valid ppl   852.78
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  6.69 | test ppl   807.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# 7 encoders
# -----------------------------------------------------------------------------------------
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 22.41 | loss  8.39 | ppl  4392.37
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 20.40 | loss  7.44 | ppl  1703.21
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 20.25 | loss  7.18 | ppl  1311.07
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 22.27 | loss  7.09 | ppl  1200.54
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 20.31 | loss  7.09 | ppl  1202.60
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 20.21 | loss  7.01 | ppl  1105.88
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 21.94 | loss  6.97 | ppl  1061.67
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 20.39 | loss  6.97 | ppl  1064.06
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 20.36 | loss  6.94 | ppl  1034.76
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 22.19 | loss  6.96 | ppl  1049.52
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 20.34 | loss  6.93 | ppl  1022.23
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 20.23 | loss  6.93 | ppl  1020.19
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 22.06 | loss  6.92 | ppl  1013.59
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 20.41 | loss  6.90 | ppl   988.44
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 66.17s | valid loss  6.81 | valid ppl   902.87
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 20.31 | loss  6.93 | ppl  1023.54
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 20.19 | loss  6.91 | ppl  1002.46
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 21.94 | loss  6.88 | ppl   971.04
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 20.21 | loss  6.90 | ppl   994.31
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 20.29 | loss  6.90 | ppl   991.21
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 22.07 | loss  6.91 | ppl  1004.18
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 20.31 | loss  6.89 | ppl   984.73
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 20.18 | loss  6.91 | ppl  1001.31
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 22.04 | loss  6.89 | ppl   983.58
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 20.21 | loss  6.91 | ppl  1003.18
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 20.20 | loss  6.88 | ppl   975.76
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 22.08 | loss  6.89 | ppl   980.73
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 20.21 | loss  6.89 | ppl   977.74
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 20.46 | loss  6.86 | ppl   953.45
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 65.28s | valid loss  6.74 | valid ppl   844.68
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 20.26 | loss  6.90 | ppl   991.33
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 22.15 | loss  6.89 | ppl   979.08
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 20.21 | loss  6.85 | ppl   947.35
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 20.30 | loss  6.89 | ppl   978.46
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 22.04 | loss  6.87 | ppl   967.02
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 20.30 | loss  6.89 | ppl   984.54
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 20.19 | loss  6.87 | ppl   962.29
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 22.14 | loss  6.89 | ppl   981.02
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 20.41 | loss  6.86 | ppl   957.40
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 20.21 | loss  6.89 | ppl   982.79
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 22.15 | loss  6.86 | ppl   957.57
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 20.22 | loss  6.86 | ppl   951.21
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 20.44 | loss  6.86 | ppl   952.12
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 21.94 | loss  6.84 | ppl   930.61
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 65.43s | valid loss  6.75 | valid ppl   855.55
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  6.70 | test ppl   809.65
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# 8 encoders
# -----------------------------------------------------------------------------------------
# | epoch   1 |   200/ 2981 batches | lr 5.00 | ms/batch 21.59 | loss  8.43 | ppl  4602.67
# | epoch   1 |   400/ 2981 batches | lr 5.00 | ms/batch 21.47 | loss  7.45 | ppl  1713.91
# | epoch   1 |   600/ 2981 batches | lr 5.00 | ms/batch 23.88 | loss  7.18 | ppl  1315.17
# | epoch   1 |   800/ 2981 batches | lr 5.00 | ms/batch 21.63 | loss  7.08 | ppl  1187.52
# | epoch   1 |  1000/ 2981 batches | lr 5.00 | ms/batch 22.69 | loss  7.06 | ppl  1161.36
# | epoch   1 |  1200/ 2981 batches | lr 5.00 | ms/batch 22.88 | loss  7.00 | ppl  1096.87
# | epoch   1 |  1400/ 2981 batches | lr 5.00 | ms/batch 21.53 | loss  6.97 | ppl  1063.73
# | epoch   1 |  1600/ 2981 batches | lr 5.00 | ms/batch 24.26 | loss  6.97 | ppl  1065.56
# | epoch   1 |  1800/ 2981 batches | lr 5.00 | ms/batch 21.62 | loss  6.95 | ppl  1038.33
# | epoch   1 |  2000/ 2981 batches | lr 5.00 | ms/batch 21.58 | loss  6.96 | ppl  1052.64
# | epoch   1 |  2200/ 2981 batches | lr 5.00 | ms/batch 24.19 | loss  6.93 | ppl  1021.90
# | epoch   1 |  2400/ 2981 batches | lr 5.00 | ms/batch 21.54 | loss  6.93 | ppl  1021.08
# | epoch   1 |  2600/ 2981 batches | lr 5.00 | ms/batch 21.48 | loss  6.92 | ppl  1016.54
# | epoch   1 |  2800/ 2981 batches | lr 5.00 | ms/batch 23.80 | loss  6.90 | ppl   990.22
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 70.21s | valid loss  6.77 | valid ppl   868.02
# -----------------------------------------------------------------------------------------
# | epoch   2 |   200/ 2981 batches | lr 4.51 | ms/batch 24.13 | loss  6.93 | ppl  1021.50
# | epoch   2 |   400/ 2981 batches | lr 4.51 | ms/batch 21.52 | loss  6.91 | ppl  1001.70
# | epoch   2 |   600/ 2981 batches | lr 4.51 | ms/batch 22.79 | loss  6.88 | ppl   972.75
# | epoch   2 |   800/ 2981 batches | lr 4.51 | ms/batch 22.98 | loss  6.91 | ppl  1000.33
# | epoch   2 |  1000/ 2981 batches | lr 4.51 | ms/batch 21.47 | loss  6.90 | ppl   989.69
# | epoch   2 |  1200/ 2981 batches | lr 4.51 | ms/batch 24.02 | loss  6.91 | ppl  1003.87
# | epoch   2 |  1400/ 2981 batches | lr 4.51 | ms/batch 21.53 | loss  6.89 | ppl   984.30
# | epoch   2 |  1600/ 2981 batches | lr 4.51 | ms/batch 21.50 | loss  6.91 | ppl  1003.81
# | epoch   2 |  1800/ 2981 batches | lr 4.51 | ms/batch 23.93 | loss  6.89 | ppl   979.19
# | epoch   2 |  2000/ 2981 batches | lr 4.51 | ms/batch 21.59 | loss  6.91 | ppl  1005.00
# | epoch   2 |  2200/ 2981 batches | lr 4.51 | ms/batch 21.57 | loss  6.89 | ppl   980.25
# | epoch   2 |  2400/ 2981 batches | lr 4.51 | ms/batch 23.99 | loss  6.89 | ppl   980.13
# | epoch   2 |  2600/ 2981 batches | lr 4.51 | ms/batch 21.32 | loss  6.89 | ppl   977.88
# | epoch   2 |  2800/ 2981 batches | lr 4.51 | ms/batch 22.89 | loss  6.86 | ppl   952.03
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 70.74s | valid loss  6.74 | valid ppl   843.59
# -----------------------------------------------------------------------------------------
# | epoch   3 |   200/ 2981 batches | lr 4.29 | ms/batch 22.98 | loss  6.90 | ppl   991.54
# | epoch   3 |   400/ 2981 batches | lr 4.29 | ms/batch 22.82 | loss  6.88 | ppl   977.46
# | epoch   3 |   600/ 2981 batches | lr 4.29 | ms/batch 21.42 | loss  6.85 | ppl   947.97
# | epoch   3 |   800/ 2981 batches | lr 4.29 | ms/batch 23.97 | loss  6.88 | ppl   976.26
# | epoch   3 |  1000/ 2981 batches | lr 4.29 | ms/batch 21.48 | loss  6.87 | ppl   965.09
# | epoch   3 |  1200/ 2981 batches | lr 4.29 | ms/batch 21.53 | loss  6.89 | ppl   983.07
# | epoch   3 |  1400/ 2981 batches | lr 4.29 | ms/batch 23.89 | loss  6.87 | ppl   964.26
# | epoch   3 |  1600/ 2981 batches | lr 4.29 | ms/batch 21.65 | loss  6.89 | ppl   979.55
# | epoch   3 |  1800/ 2981 batches | lr 4.29 | ms/batch 21.62 | loss  6.87 | ppl   959.11
# | epoch   3 |  2000/ 2981 batches | lr 4.29 | ms/batch 23.95 | loss  6.89 | ppl   984.83
# | epoch   3 |  2200/ 2981 batches | lr 4.29 | ms/batch 21.66 | loss  6.86 | ppl   957.79
# | epoch   3 |  2400/ 2981 batches | lr 4.29 | ms/batch 23.02 | loss  6.85 | ppl   948.35
# | epoch   3 |  2600/ 2981 batches | lr 4.29 | ms/batch 22.57 | loss  6.86 | ppl   949.94
# | epoch   3 |  2800/ 2981 batches | lr 4.29 | ms/batch 21.41 | loss  6.84 | ppl   929.86
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 70.63s | valid loss  6.75 | valid ppl   856.08
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | End of training | test loss  6.70 | test ppl   810.37
# -----------------------------------------------------------------------------------------

# %%
plt.bar(nlayers_range, test_losses)
plt.title('Test performance - Number of encoders')
plt.xlabel('Number of encorders')
plt.ylabel('Test performance')
plt.show()

for val_losses in val_epoch_losses:
    plt.plot(range(1, epochs+1), val_losses)
legend = ['{} encoders'.format(i) for i in nlayers_range]
plt.title('Validation performance - Number of encoders')
plt.legend(legend)
plt.xlabel('Number of epochs')
plt.ylabel('Validation performance')
plt.show()
